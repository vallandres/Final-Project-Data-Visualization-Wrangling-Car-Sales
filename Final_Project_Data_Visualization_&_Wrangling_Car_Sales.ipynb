# %% [markdown]
# #**Final Project Data Visualization & Wrangling**

# %% [markdown]
# ##**Background of Problem**

# %% [markdown]
# Perusahaan mobil menghadapi tantangan untuk mempertahankan pertumbuhan penjualan yang signifikan yang telah mereka alami dalam beberapa bulan terakhir. Meskipun peningkatan penjualan merupakan hal yang positif, tetapi untuk menjaga momentum ini dan memastikan pertumbuhan bisnis yang berkelanjutan, perusahaan perlu memahami faktor-faktor yang mendasari peningkatan tersebut. Selain itu, mereka juga dihadapkan pada persaingan sengit di pasar otomotif, yang menuntut strategi yang efektif untuk memperkuat posisi mereka di pasar. Sehingga mereka memanfaatkan peningkatan penjualan untuk mencapai pertumbuhan bisnis sebesar 30% pada tahun 2024 dan memperkuat posisi dealer dalam pasar otomotif.

# %% [markdown]
# ## **Objective**

# %% [markdown]
# Tujuan dari analisis data ini adalah untuk memberikan wawasan yang mendalam tentang kinerja penjualan mobil perusahaan dari tahun 2022 hingga 2023. Fokusnya adalah pada pemahaman tren penjualan, preferensi pelanggan, dan kinerja dealer. Dengan memahami lebih baik data penjualan mereka, perusahaan berharap dapat mengambil langkah-langkah strategis untuk meningkatkan kinerja penjualan dan memperkuat posisi mereka dalam pasar otomotif. Di sini kita membaginya menjadi empat petanyaan, yaitu:
#
#
# 1. Bagaimana tren penjualan mobil dari tahun 2022 hingga 2023, dan bagaimana pola-pola tersebut dapat memberikan wawasan tentang pertumbuhan atau penurunan penjualan perusahaan?
# 2. Apa preferensi utama pelanggan terhadap produk, seperti model, jenis transmisi, warna, atau fitur lainnya, berdasarkan analisis data penjualan?
# 3. Bagaimana kinerja dealer-dealer mobil pada region yang terlibat dalam penjualan, dan bagaimana perbandingannya dengan kinerja dealer-dealer pada region lainnya dalam pasar yang sama?

# %% [markdown]
# ##**Goals**

# %% [markdown]
# Berdasarkan tujuan dan latar belakang masalah di atas, beberapa goals yang mungkin dapat diidentifikasi adalah:
#
# 1. Mengidentifikasi tren penjualan mobil yang dapat dimanfaatkan untuk meningkatkan strategi pemasaran dan penjualan.
# 2. Mengidentifikasi preferensi pelanggan.
# 3. Meningkatkan penjualan mobil sebesar 30% pada tahun 2024 mendatang.

# %% [markdown]
# ##**Dataset**

# %% [markdown]
# Atribut-atribut dalam dataset ini adalah:
#
# 1. Car_id : daftar nomor ID mobil
# 2. Date : tanggal transaksi penjualan mobil.
# 3. Customer Name : Nama pelanggan yang membeli mobil.
# 4. Gender : jenis kelamin pelanggan (Laki-laki atau Perempuan).
# 5. Annual Income : Pendapatan pelanggan.
# 6. Dealer_Name : Nama dealer mobil.
# 7. Company : Nama perusahaan atau merek mobil.
# 8. Model : Nama model mobil.
# 9. Engine : Spesifikasi mesin mobil.
# 10. Transmission : Jenis transmisi pada mobil (Otomatis atau Manual).
# 11. Color : Warna exterior mobil.
# 12. Price ($) : Harga mobil yang dijual.
# 13. Dealer_No : Nomor dealer yang terkait dengan penjualan.
# 14. Body Style : Style atau desain bodi mobil (misalnya Sedan, SUV).
# 15. Phone : Nomor telepon yang terkait dengan penjual mobil.
# 16. Dealer_Region : Wilayah geografis atau lokasi dealer mobil.

# %% [markdown]
# ##**Data Wrangling**

# %%
# Import library yang dibutuhkan

# Library pengolahan data
import pandas as pd
import numpy as np

# Library visualisasi
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings untuk mengabaikan atau
# menyembunyikan pesan peringatan (warnings) yang mungkin muncul selama eksekusi program
import warnings
warnings.filterwarnings('ignore')

# %%
# Read data dari file
df = pd.read_csv ('Car Sales.xlsx - car_data.csv')

# Tampilkan 5 data teratas
df.head()
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
#
#                            Dealer_Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                       Engine Transmission       Color  Price ($)  Dealer_No   \
# 0  DoubleÂ Overhead Camshaft         Auto       Black      26000  06457-3834
# ...

# %%
# Dimensi dataset
row, columns = df.shape

print(f"Dataset terdiri atas {row} baris dan {columns} kolom")
# Out:
# Dataset terdiri atas 23906 baris dan 16 kolom

# %%
# Info dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23906 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %%
# Menampilkan ringkasan statistik deskriptif dari DataFrame ('df')
df.describe()
# Out:
#        Annual Income     Price ($)         Phone
# count   2.390600e+04  23906.000000  2.390600e+04
# mean    8.308403e+05  28090.247846  7.497741e+06
# std     7.200064e+05  14788.687608  8.674920e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746495e+06
# 50%     7.350000e+05  23000.000000  7.496198e+06
# 75%     1.175750e+06  34000.000000  8.248146e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %%
# Menampilkan angka dalam format desimal standar agar dapat dilihat dengan mudah
pd.options.display.float_format = '{:.2f}'.format

# Menjalankan kembali describe() untuk melihat output dengan format desimal standar
print(df.describe())
# Out:
#        Annual Income  Price ($)      Phone
# count       23906.00   23906.00   23906.00
# mean       830840.29   28090.25 7497740.61
# std        720006.40   14788.69  867492.00
# min         10080.00    1200.00 6000101.00
# 25%        386000.00   18001.00 6746495.00
# 50%        735000.00   23000.00 7496197.50
# 75%       1175750.00   34000.00 8248146.25
# max      11200000.00   85800.00 8999579.00

# %%
# Mengecek data duplikat
df.duplicated(keep=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23901    False
# 23902    False
# 23903    False
# 23904    False
# 23905    False
# Length: 23906, dtype: bool

# %%
# Menghitung jumlah duplikat dan non-duplikat
count_duplicates = df.duplicated(keep=False).value_counts()

# Menampilkan hasil
print("Jumlah duplikat:", count_duplicates[True] if True in count_duplicates else 0)
print("Jumlah non-duplikat:", count_duplicates[False] if False in count_duplicates else 0)
# Out:
# Jumlah duplikat: 0
# Jumlah non-duplikat: 23906

# %%
# Cek frekuensi nan tiap kolom
df.isna().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    0
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %%
# Cek data pada kolom Date
df.Date.head()
# Out:
# 0    1/2/2022
# 1    1/2/2022
# 2    1/2/2022
# 3    1/2/2022
# 4    1/2/2022
# Name: Date, dtype: object

# %%
# Convert kolom host_since
df.Date = pd.to_datetime(df.Date, yearfirst=True)

# Tampilkan data tanggal setelah diconvert
df.Date
# Out:
# 0       2022-01-02
# 1       2022-01-02
# 2       2022-01-02
# 3       2022-01-02
# 4       2022-01-02
#            ...
# 23901   2023-12-31
# 23902   2023-12-31
# 23903   2023-12-31
# 23904   2023-12-31
# 23905   2023-12-31
# Name: Date, Length: 23906, dtype: datetime64[ns]

# %%
# Cek outlier pada kolom Annual Income
# Pilih kolom-kolom yang mengandung outlier
outlier_columns = ['Annual Income']

# Buat boxplot untuk setiap kolom
plt.figure(figsize=(6, 4))
sns.boxplot(data=df[outlier_columns])
plt.title('Boxplot of Outlier Columns')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
# Memperlihatkan oulier dengan bentuk histogram
# Memberikan variasi gambaran untuk melihat distribusi data dan bentuknya
# Buat figure & axes
fig, ax = plt.subplots(figsize=(10, 6))

# Buat histogram plot Annual Income
sns.histplot(data=df,
             x="Annual Income",
             bins=100,
             ax=ax)

plt.show()

# %%
# Deskripsi statistik dari kolom Annual Income
df["Annual Income"].describe()
# Out:
# count      23906.00
# mean      830840.29
# std       720006.40
# min        10080.00
# 25%       386000.00
# 50%       735000.00
# 75%      1175750.00
# max     11200000.00
# Name: Annual Income, dtype: float64

# %%
# Menentukan jika suatu data adalah outlier, apabila nilainya lebih besar dari Q3 + 1.5 IQR
# Cari Q1 & Q3
Q1 = df['Annual Income'].quantile(0.25)
Q3 = df['Annual Income'].quantile(0.75)

print(f"Q1 : {Q1:.2f}")
print(f"Q3 : {Q3:.2f}")
# Out:
# Q1 : 386000.00
# Q3 : 1175750.00

# %%
# Menghitung IQR
IQR = Q3 - Q1

# Menghitung batas atas (Maximum Boundary)
max_bound = Q3 + 1.5 * IQR

print(f"IQR : {IQR:.2f}")
print(f"Maximum Boundary : {max_bound:.2f}")
# Out:
# IQR : 789750.00
# Maximum Boundary : 2360375.00

# %%
# Filter data tanpa outlier
df = df[df["Annual Income"] < max_bound]

# Validasi hasil filter
df["Annual Income"].describe()
# Out:
# count     23090.00
# mean     749642.25
# std      563609.76
# min       10080.00
# 25%      360000.00
# 50%      715000.00
# 75%     1100000.00
# max     2360000.00
# Name: Annual Income, dtype: float64

# %%
# Cek outlier pada kolom Annual Income setelah difilter
# Pilih kolom yang mengandung outlier
outlier_columns = ['Annual Income']

# Buat boxplot untuk setiap kolom
plt.figure(figsize=(6, 4))
sns.boxplot(data=df[outlier_columns])
plt.title('Boxplot of Outlier Columns')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
# Cek outlier pada kolom Annual Income setelah difilter dengan histogram
# Buat figure & axes
fig, ax = plt.subplots(figsize = (10, 6))

# Buat histogram plot Annual Income
sns.histplot(data = df,
             x = "Annual Income",
             bins = 100,
             ax = ax)

plt.show()

# %%
# Cek outlier pada kolom Price ($)
# Pilih kolom yang mengandung outlier
outlier_columns = ['Price ($)']

# Buat boxplot untuk kolom
plt.figure(figsize=(6, 4))
sns.boxplot(data=df[outlier_columns])
plt.title('Boxplot of Outlier Columns')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
# Memperlihatkan oulier dengan bentuk histogram
# Memberikan variasi gambaran untuk melihat distribusi data dan bentuknya
# Buat figure & axes
fig, ax = plt.subplots(figsize=(10, 6))

# Buat histogram plot Price
sns.histplot(data=df,
             x="Price ($)",
             bins=100,
             ax=ax)

plt.show()

# %%
# Deskripsi statistik dari kolom price
df["Price ($)"].describe()
# Out:
# count   23090.00
# mean    28056.28
# std     14772.94
# min      1200.00
# 25%     18001.00
# 50%     23000.00
# 75%     34000.00
# max     85800.00
# Name: Price ($), dtype: float64

# %%
# Menentukan jika suatu data adalah outlier, apabila nilainya lebih besar dari Q3 + 1.5 IQR
# Cari Q1 & Q3
Q1 = df['Price ($)'].quantile(0.25)
Q3 = df['Price ($)'].quantile(0.75)

print(f"Q1 : {Q1:.2f}")
print(f"Q3 : {Q3:.2f}")
# Out:
# Q1 : 18001.00
# Q3 : 34000.00

# %%
# Menghitung IQR
IQR = Q3 - Q1

# Menghitung batas atas (Maximum Boundary)
max_bound = Q3 + 1.5 * IQR

print(f"IQR : {IQR:.2f}")
print(f"Maximum Boundary : {max_bound:.2f}")
# Out:
# IQR : 15999.00
# Maximum Boundary : 57998.50

# %%
# Filter data tanpa outlier
df = df[df["Price ($)"] < max_bound]

# Validasi hasil filter
df["Price ($)"].describe()
# Out:
# count   21697.00
# mean    25429.09
# std     10678.53
# min      1200.00
# 25%     18000.00
# 50%     22001.00
# 75%     31000.00
# max     57990.00
# Name: Price ($), dtype: float64

# %%
# Cek outlier pada kolom Annual Income setelah difilter
# Pilih kolom-kolom yang mengandung outlier
outlier_columns = ['Price ($)']

# Buat boxplot untuk setiap kolom
plt.figure(figsize=(6, 4))
sns.boxplot(data=df[outlier_columns])
plt.title('Boxplot of Outlier Columns')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
# Cek outlier pada kolom Price ($) setelah difilter dengan histogram
# Buat figure & axes
fig, ax = plt.subplots(figsize = (10, 6))

# Buat histogram plot price
sns.histplot(data = df,
             x = "Price ($)",
             bins = 100,
             ax = ax)

plt.show()

# %%
# Loop melalui setiap kolom dan mencetak nilai uniknya
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values in column '{column}': {unique_values}")
# Out:
# Unique values in column 'Car_id': ['C_CND_000001' 'C_CND_000002' 'C_CND_000003' ... 'C_CND_023904'
#  'C_CND_023905' 'C_CND_023906']
# Unique values in column 'Date': ['2022-01-02T00:00:00.000000000' '2022-01-03T00:00:00.000000000'
#  '2022-01-04T00:00:00.000000000' '2022-01-05T00:00:00.000000000'
#  '2022-01-06T00:00:00.000000000' '2022-01-09T00:00:00.000000000'
#  '2022-01-10T00:00:00.000000000' '2022-01-12T00:00:00.000000000'
#  '2022-01-13T00:00:00.000000000' '2022-01-17T00:00:00.000000000'
#  '2022-01-19T00:00:00.000000000' '2022-01-21T00:00:00.000000000'
#  '2022-01-23T00:00:00.000000000' '2022-01-24T00:00:00.000000000'
#  '2022-01-26T00:00:00.000000000' '2022-01-27T00:00:00.000000000'
#  '2022-01-28T00:00:00.000000000' '2022-01-30T00:00:00.000000000'
#  '2022-01-31T00:00:00.000000000' '2022-02-03T00:00:00.000000000'
#  '2022-02-06T00:00:00.000000000' '2022-02-07T00:00:00.000000000'
#  '2022-02-08T00:00:00.000000000' '2022-02-09T00:00:00.000000000'
# ...

# %%
# Mengubah nama agar konsisten
df['Engine'] = df['Engine'].replace('DoubleÃ\x82Â\xa0Overhead Camshaft', 'DoubleÃ Overhead Camshaft')

# %%
df
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001 2022-01-02     Geraldine    Male          13500
# 1      C_CND_000002 2022-01-02           Gia    Male        1480000
# 2      C_CND_000003 2022-01-02        Gianna    Male        1035000
# 3      C_CND_000004 2022-01-02       Giselle    Male          13500
# 4      C_CND_000005 2022-01-02         Grace    Male        1465000
# ...             ...        ...           ...     ...            ...
# 23901  C_CND_023902 2023-12-31        Martin    Male          13500
# 23902  C_CND_023903 2023-12-31         Jimmy  Female         900000
# 23903  C_CND_023904 2023-12-31          Emma    Male         705000
# 23904  C_CND_023905 2023-12-31      Victoire    Male          13500
# 23905  C_CND_023906 2023-12-31       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
# Download file yang akan dimasukkan ke tableau
df.to_csv('clean data.csv', index=False)
